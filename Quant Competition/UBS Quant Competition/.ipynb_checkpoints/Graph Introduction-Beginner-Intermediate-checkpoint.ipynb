# %% [markdown]
# ##  Graph Introduction, https://python-graph-gallery.com/322-network-layout-possibilities/

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ### Build a dataframe with your connections

# %%
df = pd.DataFrame(
    {'from':['A', 'B', 'C','A','E','F','E','G','G','D','F'], 
     'to':['D', 'A', 'E','C','A','F','G','D','B','G','C']})
df
G=nx.from_pandas_edgelist(df, 'from', 'to')
G
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.fruchterman_reingold_layout(G))
plt.title("fruchterman_reingold")
# Out:
#    from to
# 0     A  D
# 1     B  A
# 2     C  E
# 3     A  C
# 4     E  A
# 5     F  F
# 6     E  G
# 7     G  D
# 8     G  B
# 9     D  G
# 10    F  C

# %% [markdown]
# ### Build your graph
# 1. https://stackoverflow.com/questions/49223057/attributeerror-module-networkx-has-no-attribute-from-pandas-dataframe
# 2. nx.fruchterman_reingold_layout, https://networkx.github.io/documentation/networkx-1.11/reference/generated/networkx.drawing.layout.fruchterman_reingold_layout.html
# 3. Layout, https://networkx.github.io/documentation/networkx-1.11/reference/drawing.html#layout

# %%
G=nx.from_pandas_edgelist(df, 'from', 'to')
G

# %%
# Fruchterman Reingold
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.fruchterman_reingold_layout(G))
plt.title("fruchterman_reingold")
# Out:
# Text(0.5,1,'fruchterman_reingold')

# %%
# Circular
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.circular_layout(G))
plt.title("circular")
# Out:
# Text(0.5,1,'circular')

# %%
# Random
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.random_layout(G))
plt.title("random")
# Out:
# Text(0.5,1,'random')

# %%
# Spectral
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.spectral_layout(G))
plt.title("spectral")
# Out:
# Text(0.5,1,'spectral')

# %%
# Spring
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.spring_layout(G))
plt.title("spring")
# Out:
# Text(0.5,1,'spring')

# %% [markdown]
# ## Application of Graph, Journal Clastering and Reference-Citation Path

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(
    {'from':['Paper 1', 'B', 'C','A','E','F','E','G','G','Paper 2','F'], 
     'to':['Paper 2', 'A', 'E','C','A','F','G','D','B','G','C']})
journal_databases = pd.DataFrame()
journal_databases["Paper 1"] = ["Intro to Laser","PH2101","www.gmail.com"]
journal_databases["Paper 2"] = ["Intro to Semicon","PH3201","www.gmail.com.lol"]
journal_output = journal_databases.transpose()
journal_output.columns = ["Name","Author","Link"]

# %%
def add_journal(name,author,link):
    #psuedocodes
    journal_databases.append()

# %%
journal_output
# Out:
#                      Name  Author               Link
# Paper 1    Intro to Laser  PH2101      www.gmail.com
# Paper 2  Intro to Semicon  PH3201  www.gmail.com.lol

# %%
df #list of references, path
# Out:
#        from       to
# 0   Paper 1  Paper 2
# 1         B        A
# 2         C        E
# 3         A        C
# 4         E        A
# 5         F        F
# 6         E        G
# 7         G        D
# 8         G        B
# 9   Paper 2        G
# 10        F        C

# %%
G=nx.from_pandas_edgelist(df, 'from', 'to')
nx.draw(G, with_labels=True, node_size=1500, node_color="skyblue", pos=nx.fruchterman_reingold_layout(G))
plt.title("fruchterman_reingold")
# Out:
# Text(0.5,1,'fruchterman_reingold')

# %%
# pseudocode, making a function to add journal

# %%
# pseudocode, make a tracing of the journal and check references and citation

# %%
# current code: manual inputting

# %%
# pseudocode, text mining from journal

# %% [markdown]
# ## References
# 1. https://networkx.github.io/documentation/stable/reference/classes/generated/networkx.Graph.number_of_edges.html#targetText=networkx.Graph.number_of_edges&targetText=Returns%20the%20number%20of%20edges,total%20number%20of%20all%20edges.
# 2. https://networkx.github.io/documentation/networkx-1.10/reference/generated/networkx.Graph.to_directed.html
