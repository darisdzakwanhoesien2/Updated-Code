# %%
#CONSTANT DATABASES
def databases():
  print("Welcome to Dzakwan automated calculation. Attached is the value of the constant that commonly used")
  proton_mass = 1.6726219 * 10**-27
  proton_charge = 1.602 * 10**-19
  vacuum_premitivity = 8.854187817 * 10**-12

#PHYSICS FUNCTIONS - PH2102 : ELECTROMAGNETICS
def year1(electric_field,time):
  #Formula 
  force = proton_charge*electric_field
  acceleration = force/proton_mass
  final_velocity = acceleration*time
  
  #Results Representation
  print("The electric force")
  print(force)
  print("The proton acceleration")
  print(acceleration)
  print("The Proton final velocity") 
  print(final_velocity)
  return ""
def electric_flux(charges):
  return charges/vacuum_premitivity
def electric_field(charge_area_density):
  return charge_area_density/vacuum_premitivity
def electric_flux_gen(area,electric_field,angle):
  return electric_field*area*math.sin(math.radians(angle))

#PHYSICS FUNCTIONS - PH2301 : PHYSICAL OPTICS
def amp_ref_elec_perp(index_1,index_2,angle_1):
  print("Reflection Amplitude - Electric Vector perpendicular to the plane of incident")
  value_1 = square_root(index_2**2 - (index_1*sin_angle(angle_1))**2)
  return (index_1*cos_angle(angle_1))-value_1/((index_1*cos_angle(angle_1))+value_1)
def trans_coef_elec_perp(index_1,index_2,angle_1):
  print("Transmission Coefficient - Electric Vector perpendicular to the plane of incident")
  value_1 = square_root(index_2**2 - (index_1*sin_angle(angle_1))**2)
  return 2*index_1*cos_angle(angle_1)/((index_1*cos_angle(angle_1))+value_1)
def snell_law_angle(index_1,index_2,angle_1):
  return sin_inverse(index_1*sin_angle(angle_1)/index_2)

#PHYSICS FUNCTIONS - PH2301 : PHYSICAL OPTICS (define it)
def formula_ph2301_week5_1(angle_1,angle_2):
  return -sin_angle(angle_1-angle_2)/sin_angle(angle_1+angle_2)
def formula_ph2301_week5_2(angle_1,angle_2):
  return 2*sin_angle(angle_1)*cos_angle(angle_2)/sin_angle(angle_1+angle_2)
def formula_ph2301_week5_3(index_1):
  2*cos_angle(24)/(cos_angle(24)+1.77*d)
def formula_ph2301_week5_4(index_1):
  print(2*25*c*cos_angle(24)/(sin_angle(24)*d+cos_angle(24)*c))

#QUADRATIC FUNCTIONS (BASIC DEFINITION, PROPERTI)
def root_calculation(a,b,c):
  print("Your equation is " + str(a) + "x^2+" + str(b) + "x+" + str(c))
  evaluate_root = b**2 - 4*a*c
  if evaluate_root < 0:
    return "Your root is imaginary value"
  elif evaluate_root == 0:
    print("Your root is both equal. It's a square equation")
    return "Your equation is (x+" + str(b/(2*a))  + ")^2"
  else:
    value_1 = (-b+math.sqrt(evaluate_root))/(2*a)
    value_2 = (-b-math.sqrt(evaluate_root))/(2*a)
    print("Your root is distincive value")
    return "Your equation is (x+" + str(value_1)  + ")(x+" + str(value_2)  + ")"
def root_properties(a,b,c):
  print("x_1 * x_2 is equal to " + str(c/a))
  print("x_1 + x_2 is equal to " + str(-b/a))
  return c/a, -b/a
