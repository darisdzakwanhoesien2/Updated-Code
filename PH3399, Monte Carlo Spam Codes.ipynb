# %% [markdown]
# cleansing_redundant_daris

# %%
#INDEXING
matrix_1 = initgrid()
#FUNCTION ADDING
matrix = np.zeros((10, 10))

for i in range(10):
  for j in range(10):
    matrix [i,j] = add_index(matrix_1,i,j)


print('50-50 Element State')
print(matrix_1)
print('\nEnergy State')
print(matrix)
print(matrix.sum())


matrix_energy_new = np.zeros((10, 10))
print(matrix_energy_new.sum())
matrix_new = swap(matrix_1)

for i in range(10):
  for j in range(10):
    matrix_energy_new [i,j] = add_index(matrix_new,i,j)


print('50-50 Element State')
print(matrix_new)
print('\nNew Energy State')
print(matrix_energy_new)
print(matrix_energy_new.sum())

# %%
import random
r = random.randint(0,1)
#print(r)

import numpy as np
import matplotlib.pyplot as plt

def initgrid(width,length):
  matrix = [(i,j) for i in range(width) for y in range(length)]
  return matrix

width = 10
length = 10
#print(initgrid)

import numpy as np
import random 

matrix = np.zeros((10,10)) 
print(matrix)

for i in range(10):
  for j in range(10):
    matrix += random.randint(0,1)
print(matrix)

import numpy as np
def matrix_test():
  matrix = np.random.randint(2, size=(10, 10))
  return matrix

print(matrix_test())

import numpy as np
import collections

matrix = np.random.randint(2, size=(10, 10))
print(matrix)
print("")
collections.Counter(matrix)

i = 1
while i = 10:
  i += 1
  print(i)

print(matrix_1)
print("")
sum = matrix_1[1,1] - matrix_1[1,2]
print(sum)

if [i,j] = 
def matrices_adding():
  

print(np.zeros((10, 10)))

# %%
spam_function

# %%
for i in matrix:
  for j in matrix:
    if i == 0 or i == 9 or j == 0 or j == 9:
      matrix_1[i-1,j] = matrix_1[9,j]
      matrix_1[i+1,j] = matrix_1[0,j]
      matrix_1[i,j-1] = matrix_1[i,9]
      matrix_1[i,j+1] = matrix_1[i,0]

# %%
spam_spam_lol_daris

# %%
random_1i = random.randint(0,9)
random_1j = random.randint(0,9)

random_2i = random.randint(0,9)
random_2j = random.randint(0,9)

def swapping(matrix,random_1i,random_1j,random_2i,random_2j):
  if matrix[random_1i,random_1j] == matrix[random_2i,random_2j]:
    return swapping(random_1i,random_1j,random_2i,random_2j)
  else:
    matrix[random_1i,random_1j] = matrix_1[random_2i,random_2j]
    matrix[random_2i,random_2j] = matrix_1[random_1i,random_1j]
    return matrix
#if same value, no energy change, if different then execute

# %%
function adding

# %%
import numpy as np
import matplotlib.pyplot as plt
import main

matrix = np.zeros((10, 10))
matrix_1 = main.initgrid()
print(matrix_1)
print(matrix)

def diff_value_abs(matrix,i,j,direction):
  if direction == "left":
    return abs(matrix[i,j]-matrix[i-1,j])
  elif direction == "right":
    return abs(matrix[i,j]-matrix[i+1,j])
  elif direction == "up":
    return abs(matrix[i,j]-matrix[i,j+1])
  elif direction == "down":  
    return abs(matrix[i,j]-matrix[i,j-1])
  else:
    return "Error"
  


def add_index(matrix,i,j):
  counter = 0
  counter += diff_value_abs(matrix,i,j,"left") + diff_value_abs(matrix,i,j,"right") + diff_value_abs(matrix,i,j,"up") +  diff_value_abs(matrix,i,j,"down") 
  return counter

print(add_index(matrix_1,1,1))

# %%
Indexing

# %%
import main
matrix_1 = main.initgrid()

def indexing():

  for i,j in matrix_1:
    if i == 0:
      matrix_1[i-1,j] = matrix_1[9,j]

    elif i == 9:
      matrix_1[i+1,j] = matrix_1[0,j]

    elif j == 0:
      matrix_1[i,j-1] = matrix_1[i,9]

    elif j == 9:
      matrix_1[i,j+1] = matrix_1[i,0]

# %%
test_2

# %%
#Import Needed library
import random
import numpy as np
import matplotlib.pyplot as plt
#Import Needed library
def initgrid():
  matrix = np.random.randint(2, size=(10, 10))
  sum = np.sum(matrix)
  if sum == 50:
    return matrix
  else:
    return initgrid()
#INDEXING
matrix_1 = initgrid()
print(matrix_1)
#FUNCTION ADDING
matrix = np.zeros((10, 10))
#FUNCTION ADDING
def diff_value_abs(matrix,i,j,direction):
  if direction == "left":    
    return abs(matrix[i,j]-matrix[i-1,j])
  elif direction == "right":
    return abs(matrix[i,j]-matrix[i+1,j])
  elif direction == "up":
    return abs(matrix[i,j]-matrix[i,j+1])
  elif direction == "down":
    return abs(matrix[i,j]-matrix[i,j-1])
  else:
    return "Error"




for i,j in matrix:
  if i == 0:
    matrix_1[i-1,j] = matrix_1[9,j]
  elif i == 9:
    matrix_1[i+1,j] = matrix_1[0,j]
  if j == 0:
    matrix_1[i,j-1] = matrix_1[i,9]
  elif j == 9:
    matrix_1[i,j+1] = matrix_1[i,0]


def add_index(matrix,i,j):
  counter = 0
  counter += diff_value_abs(matrix,i,j,"left") + diff_value_abs(matrix,i,j,"right") + diff_value_abs(matrix,i,j,"up") +  diff_value_abs(matrix,i,j,"down") 
  return counter
  
for i in range(9):
  for j in range(9):
    matrix [i,j] = add_index(matrix_1,i,j)

print(matrix)

# %%
test_daris_170220_lol

# %%
#INDEXING
#FUNCTION ADDING
#FUNCTION ADDING



#There are several function and matrix made
  # (independent) matrix_1 = random matrix
  # (independent) matrix = old empty matrix to put the value
  # matrix_energy_new = new random matrix to put the value after swapped
  # matrix_new = matrix after swap 

# there is a swap function created //swap()
  # matrix_1 -> matrix_new

# there is a need to have a function to add on the matrix //add()//
  # matrix_1 -> matrix
  # matrix_new -> matrix_energy_new

def add(matrix_old,matrix_new):
  for i in range(10):
    for j in range(10):
      matrix_new[i,j] = add_index(matrix_old,i,j)
  return matrix_new    

matrix = add(matrix_1,matrix)
matrix_energy_new = add(matrix_new,matrix_energy_new)

#there is a need to add on the counter to count how much is the function iterate
def acceptance(): #matrix,matrix_energy_new

  matrix_1 = initgrid()
  matrix = np.zeros((10, 10))
  matrix_energy_new = np.zeros((10, 10))

  matrix_new = swap(matrix_1)

  matrix = add(matrix_1,matrix)
  matrix_energy_new = add(matrix_new,matrix_energy_new)

  if matrix_energy_new.sum() > matrix.sum():
    print('50-50 Element State')
    print(matrix_1)
    print('\nEnergy State')
    print(matrix)
    print(matrix.sum())

    print('50-50 Element State')
    print(matrix_new)
    print('\nNew Energy State')
    print(matrix_energy_new)
    print(matrix_energy_new.sum())
  else:
    return swap(matrix)

# %%
swap

# %%
def swap():
  rdm1 = random.randint(10)
  rdm2 = random.randint(10)
  rdm3 = random.randint(10)
  rdm4 = random.randint(10)
  if matrix_1[rdm1,rdm2] == 1 and matrix_1[rdm3,rdm4] == 0:
    store = matrix_1[rdm3,rdm4]
    matrix_1[rdm3,rdm4] = matrix_1[rdm1,rdm2]
    matrix_1[rdm1,rdm2] = store
    return
  elif matrix_1[rdm3,rdm4] == 0 and matrix_1[rdm1,rdm2] == 1:
    store = matrix_1[rdm3,rdm4]
    matrix_1[rdm3,rdm4] = matrix_1[rdm1,rdm2]
    matrix_1[rdm1,rdm2] = store
    return
  else:
    return swap()

# %%
test_daris

# %%
print("\n Daris Codes \n ")

#Set the box size/grid (set to be 10)
box = 10 #random.randint(0,100)

#Parameter
energy = 0 

#Set the function to iterate, while
for i in range(box):
  for j in range(box):
    r = random.randint(0,1)

def diff_value_abs_general(matrix,i,j):
  return abs(matrix[i,j]-matrix[i-1,j])

#Corner Value (0,0)
value = 0
value += diff_value_abs_general(matrix,0,1) + diff_value_abs_general(matrix,1,0) + diff_value_abs_general(matrix,0,9) + diff_value_abs_general(matrix,9,0)

#Corner Value (0,9)
value = 0
value += diff_value_abs_general(matrix,0,1) + diff_value_abs_general(matrix,1,0) + diff_value_abs_general(matrix,0,0) + diff_value_abs_general(matrix,9,0)

#Corner Value (0,0)
value = 0
value += diff_value_abs_general(matrix,0,1) + diff_value_abs_general(matrix,1,0) + diff_value_abs_general(matrix,0,9) + diff_value_abs_general(matrix,9,0)

#Corner Value (0,0)
value = 0
value += diff_value_abs_general(matrix,0,1) + diff_value_abs_general(matrix,1,0) + diff_value_abs_general(matrix,0,9) + diff_value_abs_general(matrix,9,0)



#Define the case, for case 1 (0,0) = (0,1)+(1,0)+(9,0)+(0,9), case 2 (0,9) = (0,8)+(1,9)+(9,9)+(0,0) for (9,0) (0,j for 1 to 8) = ()
 
def add_boundary_left(matrix,i,j):
  if i=0
  counter = 0
  for j in range(10):
    counter += diff_value_abs_general(matrix,i,j)



for i in range(9):
  for j in range(9):
    if i == 0:
      matrix[i-1,j] = matrix[9,j]
    elif i == 9:
      matrix[i+1,j] = matrix[0,j]
    elif j == 0:
      matrix[i,j-1] = matrix[i,9]
    elif j == 9:
      matrix[i,j+1] = matrix[i,0]


def addition_matrix(matrix_old,matrix_new):
  for i in range(10):
    for j in range(10):
      matrix_new[i,j] = add_index(matrix_old,i,j)

#There are some concern on the function, that the regular model are limited due to computational timing on the code, it can be reduced by just measuring the number locally. The function is satisfy the visualization of the matrix and process, but for research

# %%
occurence_total = np.zeros(10)

for i in range(10):
  occurence = np.zeros(10)
  occurence[i] = np.sum(matrix_density == i/9)
  occurence_total += occurence
occurence_total

# %%
unique, counts = np.unique(matrix_density, return_counts=1)
unique_list = list(unique)
counts_list = list(counts)

unique, counts
